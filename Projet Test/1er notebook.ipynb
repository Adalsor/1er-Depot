# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# 0      Male    160.119.8.119         Canada      $5.36   NaN
# 1    Female   210.51.172.132         Canada      $8.32   NaN
# 2      Male    213.8.101.145  United States      $3.73  20.0
# 3    Female    5.140.237.101  United States      $3.70  20.0
# 4      Male  106.252.162.233        Morocco      $9.24  20.0
# ..      ...              ...            ...        ...   ...
# 995  Female   193.84.247.144         France      $3.63   NaN
# 996  Female   188.219.12.109            NaN      $4.59  20.0
# 997    Male     199.80.60.87  United States      $7.54  20.0
# 998    Male      0.183.63.11  United States      $5.81   NaN
# 999     NaN   170.193.249.83         Canada      $8.01  20.0
#
# [1000 rows x 10 columns]

# %%
df.set_index('id', inplace=True)

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#            ip_address        country price_paid   tax
# id
# 1       160.119.8.119         Canada      $5.36   NaN
# 2      210.51.172.132         Canada      $8.32   NaN
# 3       213.8.101.145  United States      $3.73  20.0
# 4       5.140.237.101  United States      $3.70  20.0
# 5     106.252.162.233        Morocco      $9.24  20.0
# ...               ...            ...        ...   ...
# 996    193.84.247.144         France      $3.63   NaN
# 997    188.219.12.109            NaN      $4.59  20.0
# 998      199.80.60.87  United States      $7.54  20.0
# 999       0.183.63.11  United States      $5.81   NaN
# 1000   170.193.249.83         Canada      $8.01  20.0
#
# [1000 rows x 9 columns]

# %%
df["price_paid"] = df["price_paid"].apply(lambda x: x.replace("$", ""))

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#            ip_address        country price_paid   tax
# id
# 1       160.119.8.119         Canada       5.36   NaN
# 2      210.51.172.132         Canada       8.32   NaN
# 3       213.8.101.145  United States       3.73  20.0
# 4       5.140.237.101  United States       3.70  20.0
# 5     106.252.162.233        Morocco       9.24  20.0
# ...               ...            ...        ...   ...
# 996    193.84.247.144         France       3.63   NaN
# 997    188.219.12.109            NaN       4.59  20.0
# 998      199.80.60.87  United States       7.54  20.0
# 999       0.183.63.11  United States       5.81   NaN
# 1000   170.193.249.83         Canada       8.01  20.0
#
# [1000 rows x 9 columns]

# %%
df["price_paid"]
# Out:
# id
# 1       5.36
# 2       8.32
# 3       3.73
# 4       3.70
# 5       9.24
#         ...
# 996     3.63
# 997     4.59
# 998     7.54
# 999     5.81
# 1000    8.01
# Name: price_paid, Length: 1000, dtype: object

# %%
df["price_paid"] = df["price_paid"].astype(float)

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#            ip_address        country  price_paid   tax
# id
# 1       160.119.8.119         Canada        5.36   NaN
# 2      210.51.172.132         Canada        8.32   NaN
# 3       213.8.101.145  United States        3.73  20.0
# 4       5.140.237.101  United States        3.70  20.0
# 5     106.252.162.233        Morocco        9.24  20.0
# ...               ...            ...         ...   ...
# 996    193.84.247.144         France        3.63   NaN
# 997    188.219.12.109            NaN        4.59  20.0
# 998      199.80.60.87  United States        7.54  20.0
# 999       0.183.63.11  United States        5.81   NaN
# 1000   170.193.249.83         Canada        8.01  20.0
#
# [1000 rows x 9 columns]

# %%
df["price_paid"]
# Out:
# id
# 1       5.36
# 2       8.32
# 3       3.73
# 4       3.70
# 5       9.24
#         ...
# 996     3.63
# 997     4.59
# 998     7.54
# 999     5.81
# 1000    8.01
# Name: price_paid, Length: 1000, dtype: float64

# %%
df[df["price_paid"] >= 5.0]
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 6     03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava     Kencott          akencott6@phoca.cz  Female
# ...          ...        ...         ...                         ...     ...
# 993   03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me    Male
# 995   03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#            ip_address        country  price_paid   tax
# id
# 1       160.119.8.119         Canada        5.36   NaN
# 2      210.51.172.132         Canada        8.32   NaN
# 5     106.252.162.233        Morocco        9.24  20.0
# 6      173.100.21.179  United States        5.82   NaN
# 7       118.251.45.43         Canada        6.29   NaN
# ...               ...            ...         ...   ...
# 993    108.73.141.204         France        9.19   NaN
# 995       7.29.168.78         France        5.68  20.0
# 998      199.80.60.87  United States        7.54  20.0
# 999       0.183.63.11  United States        5.81   NaN
# 1000   170.193.249.83         Canada        8.01  20.0
#
# [696 rows x 9 columns]

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#            ip_address        country  price_paid   tax
# id
# 1       160.119.8.119         Canada        5.36   NaN
# 2      210.51.172.132         Canada        8.32   NaN
# 3       213.8.101.145  United States        3.73  20.0
# 4       5.140.237.101  United States        3.70  20.0
# 5     106.252.162.233        Morocco        9.24  20.0
# ...               ...            ...         ...   ...
# 996    193.84.247.144         France        3.63   NaN
# 997    188.219.12.109            NaN        4.59  20.0
# 998      199.80.60.87  United States        7.54  20.0
# 999       0.183.63.11  United States        5.81   NaN
# 1000   170.193.249.83         Canada        8.01  20.0
#
# [1000 rows x 9 columns]

# %%
df.drop("ip_address", axis=1, inplace=True)

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 1            Canada        5.36   NaN
# 2            Canada        8.32   NaN
# 3     United States        3.73  20.0
# 4     United States        3.70  20.0
# 5           Morocco        9.24  20.0
# ...             ...         ...   ...
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 998   United States        7.54  20.0
# 999   United States        5.81   NaN
# 1000         Canada        8.01  20.0
#
# [1000 rows x 8 columns]

# %%
df_male = df[df["gender"] == "Male"]
df_male
# Out:
#            date first_name   last_name                       email gender  \
# id
# 1    03/28/2021    Marylin      Alders        malders0@shop-pro.jp   Male
# 3    03/17/2021        Erl  Kilminster       ekilminster2@etsy.com   Male
# 5    03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com   Male
# 8    03/08/2021       Codi     Feasley            cfeasley7@ed.gov   Male
# 9    03/09/2021     Waylon    Heersema       wheersema8@tumblr.com   Male
# ..          ...        ...         ...                         ...    ...
# 992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu   Male
# 993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me   Male
# 994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk   Male
# 998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com   Male
# 999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp   Male
#
#            country  price_paid   tax
# id
# 1           Canada        5.36   NaN
# 3    United States        3.73  20.0
# 5          Morocco        9.24  20.0
# 8           France        3.01  20.0
# 9           Canada        3.70  20.0
# ..             ...         ...   ...
# 992        Morocco        5.05  20.0
# 993         France        9.19   NaN
# 994         France        4.31   NaN
# 998  United States        7.54  20.0
# 999  United States        5.81   NaN
#
# [438 rows x 8 columns]

# %%
df.set_index("gender")
# Out:
#               date first_name   last_name                       email  \
# gender
# Male    03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# Female  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# Male    03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# Female  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# Male    03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ...            ...        ...         ...                         ...
# Female  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# Female  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# Male    03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# Male    03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# NaN     03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#               country  price_paid   tax
# gender
# Male           Canada        5.36   NaN
# Female         Canada        8.32   NaN
# Male    United States        3.73  20.0
# Female  United States        3.70  20.0
# Male          Morocco        9.24  20.0
# ...               ...         ...   ...
# Female         France        3.63   NaN
# Female            NaN        4.59  20.0
# Male    United States        7.54  20.0
# Male    United States        5.81   NaN
# NaN            Canada        8.01  20.0
#
# [1000 rows x 7 columns]

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 1            Canada        5.36   NaN
# 2            Canada        8.32   NaN
# 3     United States        3.73  20.0
# 4     United States        3.70  20.0
# 5           Morocco        9.24  20.0
# ...             ...         ...   ...
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 998   United States        7.54  20.0
# 999   United States        5.81   NaN
# 1000         Canada        8.01  20.0
#
# [1000 rows x 8 columns]

# %%
df.drop(3, axis=0)
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 6     03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu  Female
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 1            Canada        5.36   NaN
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 5           Morocco        9.24  20.0
# 6     United States        5.82   NaN
# ...             ...         ...   ...
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 998   United States        7.54  20.0
# 999   United States        5.81   NaN
# 1000         Canada        8.01  20.0
#
# [999 rows x 8 columns]

# %%
df.drop(df[df["gender"] == "Male"].index)
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df[df["gender"] == "Male"].index
# Out:
# Index([  1,   3,   5,   8,   9,  10,  11,  12,  20,  22,
#        ...
#        981, 984, 987, 988, 991, 992, 993, 994, 998, 999],
#       dtype='int64', name='id', length=438)

# %%
df_email = df.set_index("email")

# %%
df_email
# Out:
#                                   date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp        03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org          03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com       03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu            03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com         03/24/2021      Kanya     Beasant    Male
# ...                                ...        ...         ...     ...
# derrigorn@elpais.com        03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz       03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp      03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       03/23/2021   Rochelle    Pringuer     NaN
#
#                                   country  price_paid   tax
# email
# malders0@shop-pro.jp               Canada        5.36   NaN
# hharridge1@gnu.org                 Canada        8.32   NaN
# ekilminster2@etsy.com       United States        3.73  20.0
# gbrantl3@umn.edu            United States        3.70  20.0
# kbeasant4@jigsy.com               Morocco        9.24  20.0
# ...                                   ...         ...   ...
# derrigorn@elpais.com               France        3.63   NaN
# arastallro@toplist.cz                 NaN        4.59  20.0
# bstickelsrp@cloudflare.com  United States        7.54  20.0
# ptesoerq@rakuten.co.jp      United States        5.81   NaN
# rpringuerrr@house.gov              Canada        8.01  20.0
#
# [1000 rows x 7 columns]

# %%
df_email[df_email["gender"] == "Male"].index
# Out:
# Index(['malders0@shop-pro.jp', 'ekilminster2@etsy.com', 'kbeasant4@jigsy.com',
#        'cfeasley7@ed.gov', 'wheersema8@tumblr.com', 'ggookes9@amazon.co.uk',
#        'lwoodcrafta@sitemeter.com', 'bwymanb@lulu.com',
#        'smounchj@rakuten.co.jp', 'mayerl@squarespace.com',
#        ...
#        'chenzer8@toplist.cz', 'rmcgralerb@wix.com',
#        'despinalre@accuweather.com', 'pbarrrf@google.de',
#        'sthorburnri@prnewswire.com', 'ecrushrj@berkeley.edu',
#        'mguilloneaurk@about.me', 'osnellerl@nhs.uk',
#        'bstickelsrp@cloudflare.com', 'ptesoerq@rakuten.co.jp'],
#       dtype='object', name='email', length=438)

# %%
df
# Out:
#             date first_name   last_name                       email  gender  \
# id
# 1     03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 2     03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 3     03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 4     03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 5     03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# ...          ...        ...         ...                         ...     ...
# 996   03/24/2021       Duff      Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame     Rastall       arastallro@toplist.cz  Female
# 998   03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com    Male
# 999   03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp    Male
# 1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 1            Canada        5.36   NaN
# 2            Canada        8.32   NaN
# 3     United States        3.73  20.0
# 4     United States        3.70  20.0
# 5           Morocco        9.24  20.0
# ...             ...         ...   ...
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 998   United States        7.54  20.0
# 999   United States        5.81   NaN
# 1000         Canada        8.01  20.0
#
# [1000 rows x 8 columns]

# %%
df.drop(df[df["gender"] == "Male"].index, inplace=True)

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df.dropna()
# Out:
#            date first_name last_name                        email  gender  \
# id
# 4    03/19/2021      Grata    Brantl             gbrantl3@umn.edu  Female
# 13   03/05/2021     Janice  Morillas   jmorillasc@miibeian.gov.cn  Female
# 15   03/21/2021     Oralie    Maryon              omaryone@va.gov  Female
# 16   03/24/2021     Julina     Faint         jfaintf@amazon.co.jp  Female
# 17   03/27/2021        Eve   Allaway         eallawayg@ebay.co.uk  Female
# ..          ...        ...       ...                          ...     ...
# 973  03/26/2021     Margie   Summons  msummonsr0@reverbnation.com  Female
# 976  03/02/2021      Leroi     Latus     llatusr3@istockphoto.com  Female
# 983  03/07/2021      Aaren   Yesinin     ayesininra@parallels.com  Female
# 989  03/07/2021       Yves    Botler   ybotlerrg@miitbeian.gov.cn  Female
# 995  03/17/2021   Carolyne  Bruntjen    cbruntjenrm@reference.com  Female
#
#            country  price_paid   tax
# id
# 4    United States        3.70  20.0
# 13          Canada        5.30  20.0
# 15   United States        4.53  20.0
# 16   United States        4.10  20.0
# 17   United States        6.44  20.0
# ..             ...         ...   ...
# 973  United States        6.05  20.0
# 976         France        5.19  20.0
# 983  United States        8.41  20.0
# 989  United States        6.10  20.0
# 995         France        5.68  20.0
#
# [308 rows x 8 columns]

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df[df["country"].notnull()]
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 989   03/07/2021       Yves        Botler  ybotlerrg@miitbeian.gov.cn  Female
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 989   United States        6.10  20.0
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 1000         Canada        8.01  20.0
#
# [533 rows x 8 columns]

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df.dropna(subset=["country"])
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 989   03/07/2021       Yves        Botler  ybotlerrg@miitbeian.gov.cn  Female
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 989   United States        6.10  20.0
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 1000         Canada        8.01  20.0
#
# [533 rows x 8 columns]

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df["test"] = 0

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax  test
# id
# 2            Canada        8.32   NaN     0
# 4     United States        3.70  20.0     0
# 6     United States        5.82   NaN     0
# 7            Canada        6.29   NaN     0
# 13           Canada        5.30  20.0     0
# ...             ...         ...   ...   ...
# 990          France        8.69  20.0     0
# 995          France        5.68  20.0     0
# 996          France        3.63   NaN     0
# 997             NaN        4.59  20.0     0
# 1000         Canada        8.01  20.0     0
#
# [562 rows x 9 columns]

# %%
del df["test"]

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   NaN
# 4     United States        3.70  20.0
# 6     United States        5.82   NaN
# 7            Canada        6.29   NaN
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   NaN
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df["tax"].fillna(0, inplace=True)
# Out:
# C:\Users\Adrien\AppData\Local\Temp\ipykernel_2156\1359472388.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["tax"].fillna(0, inplace=True)

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax
# id
# 2            Canada        8.32   0.0
# 4     United States        3.70  20.0
# 6     United States        5.82   0.0
# 7            Canada        6.29   0.0
# 13           Canada        5.30  20.0
# ...             ...         ...   ...
# 990          France        8.69  20.0
# 995          France        5.68  20.0
# 996          France        3.63   0.0
# 997             NaN        4.59  20.0
# 1000         Canada        8.01  20.0
#
# [562 rows x 8 columns]

# %%
df["price_total"] = df["price_paid"] * (1 - df["tax"] / 100)

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax  price_total
# id
# 2            Canada        8.32   0.0        8.320
# 4     United States        3.70  20.0        2.960
# 6     United States        5.82   0.0        5.820
# 7            Canada        6.29   0.0        6.290
# 13           Canada        5.30  20.0        4.240
# ...             ...         ...   ...          ...
# 990          France        8.69  20.0        6.952
# 995          France        5.68  20.0        4.544
# 996          France        3.63   0.0        3.630
# 997             NaN        4.59  20.0        3.672
# 1000         Canada        8.01  20.0        6.408
#
# [562 rows x 9 columns]

# %%
countries = {"United States": "UN", "France": "FR", "Canada": "CA", "Morocco": "MA"}

# %%
df["country_code"] = df["country"].map(countries)

# %%
df
# Out:
#             date first_name     last_name                       email  gender  \
# id
# 2     03/19/2021      Hinda      Harridge          hharridge1@gnu.org  Female
# 4     03/19/2021      Grata        Brantl            gbrantl3@umn.edu  Female
# 6     03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu  Female
# 7     03/14/2021        Ava       Kencott          akencott6@phoca.cz  Female
# 13    03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn  Female
# ...          ...        ...           ...                         ...     ...
# 990   03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org     NaN
# 995   03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com  Female
# 996   03/24/2021       Duff        Errigo        derrigorn@elpais.com  Female
# 997   03/17/2021        Ame       Rastall       arastallro@toplist.cz  Female
# 1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov     NaN
#
#             country  price_paid   tax  price_total country_code
# id
# 2            Canada        8.32   0.0        8.320           CA
# 4     United States        3.70  20.0        2.960           UN
# 6     United States        5.82   0.0        5.820           UN
# 7            Canada        6.29   0.0        6.290           CA
# 13           Canada        5.30  20.0        4.240           CA
# ...             ...         ...   ...          ...          ...
# 990          France        8.69  20.0        6.952           FR
# 995          France        5.68  20.0        4.544           FR
# 996          France        3.63   0.0        3.630           FR
# 997             NaN        4.59  20.0        3.672          NaN
# 1000         Canada        8.01  20.0        6.408           CA
#
# [562 rows x 10 columns]

# %%
df["price_paid"].mean()
# Out:
# np.float64(6.456085409252669)

# %%
df["price_paid"].sum()
# Out:
# np.float64(3628.32)

# %%
df["price_paid"].min()
# Out:
# np.float64(3.02)

# %%
df["price_paid"].max()
# Out:
# np.float64(10.0)

# %%
df["country"].unique()
# Out:
# array(['Canada', 'United States', 'France', nan, 'Morocco'], dtype=object)

# %%
df["country"].value_counts(normalize=True)
# Out:
# country
# France           0.425891
# United States    0.354597
# Canada           0.161351
# Morocco          0.058161
# Name: proportion, dtype: float64

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    493
# Name: count, dtype: int64

# %%
df.groupby("country").sum()
# Out:
#                                                             date  \
# country
# Canada         03/19/202103/14/202103/05/202103/22/202103/14/...
# France         03/24/202103/16/202103/12/202103/10/202103/02/...
# Morocco        03/28/202103/21/202103/25/202103/07/202103/01/...
# United States  03/19/202103/25/202103/21/202103/24/202103/27/...
#
#                                                       first_name  \
# country
# Canada         HindaAvaJaniceMatthusMurdockNoveliaMarcusKelbe...
# France         CullJudyeJeffreyJilleneTreschaFilberteKeeneGra...
# Morocco        TommiRandyKristalEthelinWillisFredericaKendalO...
# United States  GrataTitosOralieJulinaEveEstaNobeElyseCamGeorg...
#
#                                                        last_name  \
# country
# Canada         HarridgeKencottMorillasSaketSpeaksNajafianHels...
# France         VassieBehanStanmanBaudiMcCuddenO'HickeyBewsyKe...
# Morocco        DitchburnTiebeKettelGorsSandercroftStuchburieH...
# United States  BrantlBraybrookeMaryonFaintAllawayBouldenStobb...
#
#                                                            email  \
# country
# Canada         hharridge1@gnu.orgakencott6@phoca.czjmorillasc...
# France         cvassied@unblog.frjbehani@google.esjstanmank@l...
# Morocco        tditchburnu@bbc.co.ukrtiebe2g@livejournal.comk...
# United States  gbrantl3@umn.edutbraybrooke5@umn.eduomaryone@v...
#
#                                                           gender  price_paid  \
# country
# Canada         FemaleFemaleFemaleFemaleFemaleFemaleFemaleFema...      558.64
# France         FemaleFemaleFemaleFemaleFemaleFemaleFemaleFema...     1443.30
# Morocco        FemaleFemaleFemaleFemaleFemaleFemaleFemaleFema...      221.59
# United States  FemaleFemaleFemaleFemaleFemaleFemaleFemaleFema...     1222.83
#
#                   tax  price_total  \
# country
# Canada         1140.0      483.834
# France         2740.0     1268.988
# Morocco         500.0      186.488
# United States  2580.0     1056.050
#
#                                                     country_code
# country
# Canada         CACACACACACACACACACACACACACACACACACACACACACACA...
# France         FRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFRFR...
# Morocco        MAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMAMA...
# United States  UNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUNUN...
